# %%
from Init.AutoDev import *

# %%
from Init.AutoDev import *

if __name__ == "__main__":
    ADConfig = AutoDev_Config()
    ADConfig.AD_Config_GetStartFile()
    ADConfig.AD_Config_Start_Stage()
    # ADConfig.AD_Config_Start_Stage(Change_Name=True,InitConfig_Backup=True)
    # ADConfig.AD_Config_Start_Stage(Change_Name=True)
    ADConfig.AD_Config_Core()
# Out:
# JSON 文件已保存: AutoDevProFile/Temporary/Temporary_InitConfig.json
# ✅ 已成功存储文件到：AutoDevProFile/Temporary/Temporary_InitConfig.json
# ✅ 192.168.56.3 可达
# ✅ 192.168.56.3 SSH可连接
# 正在比对192.168.56.3的设备名是否为：AutoConfig_R1
# ✅ 192.168.56.4 可达
# ✅ 192.168.56.4 SSH可连接
# 正在比对192.168.56.4的设备名是否为：AutoConfig_R2
# ✅ 192.168.56.5 可达
# ✅ 192.168.56.5 SSH可连接
# 正在比对192.168.56.5的设备名是否为：AutoConfig_R3
# ✅ 已对所有设备进行检查。
# JSON 文件已保存: AutoDevProFile/Temporary/Temporary_DevicStatus.json
# ✅ 已成功存储文件到：AutoDevProFile/Temporary/Temporary_DevicStatus.json
# 🔧 正在配置设备: AutoConfig_R1
#   📄 处理表单: Port_IP_Sheet(Router)
#   📄 处理表单: IP_Route_Static_Sheet
# [{'command': 'system-view ', 'mode': 'Quick', 'time': ''}, {'command': 'interface G 0/0', 'mode': 'Quick', 'time': ''}, {'command': 'ip address 10.10.10.1 255.255.255.0', 'mode': 'Quick', 'time': ''}, {'command': 'quit ', 'mode': 'Recv', 'time': ''}, {'command': 'interface loopback 0', 'mode': 'Quick', 'time': ''}, {'command': 'ip address 1.1.1.1 255.255.255.255', 'mode': 'Quick', 'time': ''}, {'command': 'quit ', 'mode': 'Recv', 'time': ''}, {'command': 'interface loopback 1', 'mode': 'Quick', 'time': ''}, {'command': 'ip address 172.16.1.0 255.255.255.0', 'mode': 'Quick', 'time': ''}, {'command': 'quit ', 'mode': 'Recv', 'time': ''}, {'command': 'interface loopback 2', 'mode': 'Quick', 'time': ''}, {'command': 'ip address 172.16.2.0 255.255.255.0', 'mode': 'Quick', 'time': ''}, {'command': 'quit ', 'mode': 'Recv', 'time': ''}, {'command': 'interface loopback 3', 'mode': 'Quick', 'time': ''}, {'command': 'ip address 172.16.3.0 255.255.255.0', 'mode': 'Quick', 'time': ''}, {'command': 'quit ', 'mode': 'Recv', 'time': ''}, {'command': 'ip route-static 10.10.11.0 255.255.255.0 10.10.10.2', 'mode': 'Quick', 'time': ''}, {'command': 'ip route-static 2.2.2.2 255.255.255.255 10.10.10.2', 'mode': 'Quick', 'time': ''}, {'command': 'ip route-static 3.3.3.3 255.255.255.255 10.10.10.2', 'mode': 'Quick', 'time': ''}, {'command': 'ip route-static 172.16.4.0 255.255.255.0 10.10.10.2', 'mode': 'Quick', 'time': ''}, {'command': 'quit ', 'mode': 'Recv', 'time': ''}]
# {'command': 'system-view ', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：system-view
# {'command': 'interface G 0/0', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：interface G 0/0
# {'command': 'ip address 10.10.10.1 255.255.255.0', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip address 10.10.10.1 255.255.255.0
# {'command': 'quit ', 'mode': 'Recv', 'time': ''}
# 执行Recv中，命令为：quit
# {'command': 'interface loopback 0', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：interface loopback 0
# {'command': 'ip address 1.1.1.1 255.255.255.255', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip address 1.1.1.1 255.255.255.255
# {'command': 'quit ', 'mode': 'Recv', 'time': ''}
# 执行Recv中，命令为：quit
# {'command': 'interface loopback 1', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：interface loopback 1
# {'command': 'ip address 172.16.1.0 255.255.255.0', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip address 172.16.1.0 255.255.255.0
# {'command': 'quit ', 'mode': 'Recv', 'time': ''}
# 执行Recv中，命令为：quit
# {'command': 'interface loopback 2', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：interface loopback 2
# {'command': 'ip address 172.16.2.0 255.255.255.0', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip address 172.16.2.0 255.255.255.0
# {'command': 'quit ', 'mode': 'Recv', 'time': ''}
# 执行Recv中，命令为：quit
# {'command': 'interface loopback 3', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：interface loopback 3
# {'command': 'ip address 172.16.3.0 255.255.255.0', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip address 172.16.3.0 255.255.255.0
# {'command': 'quit ', 'mode': 'Recv', 'time': ''}
# 执行Recv中，命令为：quit
# {'command': 'ip route-static 10.10.11.0 255.255.255.0 10.10.10.2', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip route-static 10.10.11.0 255.255.255.0 10.10.10.2
# {'command': 'ip route-static 2.2.2.2 255.255.255.255 10.10.10.2', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip route-static 2.2.2.2 255.255.255.255 10.10.10.2
# {'command': 'ip route-static 3.3.3.3 255.255.255.255 10.10.10.2', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip route-static 3.3.3.3 255.255.255.255 10.10.10.2
# {'command': 'ip route-static 172.16.4.0 255.255.255.0 10.10.10.2', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip route-static 172.16.4.0 255.255.255.0 10.10.10.2
# {'command': 'quit ', 'mode': 'Recv', 'time': ''}
# 执行Recv中，命令为：quit
# 执行Quicky中，命令为：
# 执行Recv中，命令为：save
# 执行Recv中，命令为：Y
# 执行Recv中，命令为：
# 执行Recv中，命令为：Y
# ✅ 设备 AutoConfig_R1 配置完成并保存
# 🔧 正在配置设备: AutoConfig_R2
#   📄 处理表单: Port_IP_Sheet(Router)
#   📄 处理表单: IP_Route_Static_Sheet
# [{'command': 'system-view ', 'mode': 'Quick', 'time': ''}, {'command': 'interface G 0/0', 'mode': 'Quick', 'time': ''}, {'command': 'ip address 10.10.11.1 255.255.255.0', 'mode': 'Quick', 'time': ''}, {'command': 'quit ', 'mode': 'Recv', 'time': ''}, {'command': 'interface G 0/1', 'mode': 'Quick', 'time': ''}, {'command': 'ip address 10.10.10.2 255.255.255.0', 'mode': 'Quick', 'time': ''}, {'command': 'quit ', 'mode': 'Recv', 'time': ''}, {'command': 'interface loopback 0', 'mode': 'Quick', 'time': ''}, {'command': 'ip address 2.2.2.2 255.255.255.255', 'mode': 'Quick', 'time': ''}, {'command': 'quit ', 'mode': 'Recv', 'time': ''}, {'command': 'ip route-static 10.10.10.0 255.255.255.0 10.10.10.1', 'mode': 'Quick', 'time': ''}, {'command': 'ip route-static 10.10.11.0 255.255.255.0 10.10.11.2', 'mode': 'Quick', 'time': ''}, {'command': 'ip route-static 1.1.1.1 255.255.255.255 10.10.10.1', 'mode': 'Quick', 'time': ''}, {'command': 'ip route-static 3.3.3.3 255.255.255.255 10.10.11.2', 'mode': 'Quick', 'time': ''}, {'command': 'ip route-static 172.16.1.0 255.255.255.0 10.10.10.1', 'mode': 'Quick', 'time': ''}, {'command': 'ip route-static 172.16.2.0 255.255.255.0 10.10.10.1', 'mode': 'Quick', 'time': ''}, {'command': 'ip route-static 172.16.3.0 255.255.255.0 10.10.10.1', 'mode': 'Quick', 'time': ''}, {'command': 'ip route-static 172.16.4.0 255.255.255.0 10.10.11.2', 'mode': 'Quick', 'time': ''}, {'command': 'quit ', 'mode': 'Recv', 'time': ''}]
# {'command': 'system-view ', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：system-view
# {'command': 'interface G 0/0', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：interface G 0/0
# {'command': 'ip address 10.10.11.1 255.255.255.0', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip address 10.10.11.1 255.255.255.0
# {'command': 'quit ', 'mode': 'Recv', 'time': ''}
# 执行Recv中，命令为：quit
# {'command': 'interface G 0/1', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：interface G 0/1
# {'command': 'ip address 10.10.10.2 255.255.255.0', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip address 10.10.10.2 255.255.255.0
# {'command': 'quit ', 'mode': 'Recv', 'time': ''}
# 执行Recv中，命令为：quit
# {'command': 'interface loopback 0', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：interface loopback 0
# {'command': 'ip address 2.2.2.2 255.255.255.255', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip address 2.2.2.2 255.255.255.255
# {'command': 'quit ', 'mode': 'Recv', 'time': ''}
# 执行Recv中，命令为：quit
# {'command': 'ip route-static 10.10.10.0 255.255.255.0 10.10.10.1', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip route-static 10.10.10.0 255.255.255.0 10.10.10.1
# {'command': 'ip route-static 10.10.11.0 255.255.255.0 10.10.11.2', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip route-static 10.10.11.0 255.255.255.0 10.10.11.2
# {'command': 'ip route-static 1.1.1.1 255.255.255.255 10.10.10.1', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip route-static 1.1.1.1 255.255.255.255 10.10.10.1
# {'command': 'ip route-static 3.3.3.3 255.255.255.255 10.10.11.2', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip route-static 3.3.3.3 255.255.255.255 10.10.11.2
# {'command': 'ip route-static 172.16.1.0 255.255.255.0 10.10.10.1', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip route-static 172.16.1.0 255.255.255.0 10.10.10.1
# {'command': 'ip route-static 172.16.2.0 255.255.255.0 10.10.10.1', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip route-static 172.16.2.0 255.255.255.0 10.10.10.1
# {'command': 'ip route-static 172.16.3.0 255.255.255.0 10.10.10.1', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip route-static 172.16.3.0 255.255.255.0 10.10.10.1
# {'command': 'ip route-static 172.16.4.0 255.255.255.0 10.10.11.2', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip route-static 172.16.4.0 255.255.255.0 10.10.11.2
# {'command': 'quit ', 'mode': 'Recv', 'time': ''}
# 执行Recv中，命令为：quit
# 执行Quicky中，命令为：
# 执行Recv中，命令为：save
# 执行Recv中，命令为：Y
# 执行Recv中，命令为：
# 执行Recv中，命令为：Y
# ✅ 设备 AutoConfig_R2 配置完成并保存
# 🔧 正在配置设备: AutoConfig_R3
#   📄 处理表单: Port_IP_Sheet(Router)
#   📄 处理表单: IP_Route_Static_Sheet
# [{'command': 'system-view ', 'mode': 'Quick', 'time': ''}, {'command': 'interface G 0/1', 'mode': 'Quick', 'time': ''}, {'command': 'ip address 10.10.11.2 255.255.255.0', 'mode': 'Quick', 'time': ''}, {'command': 'quit ', 'mode': 'Recv', 'time': ''}, {'command': 'interface loopback 0', 'mode': 'Quick', 'time': ''}, {'command': 'ip address 3.3.3.3 255.255.255.255', 'mode': 'Quick', 'time': ''}, {'command': 'quit ', 'mode': 'Recv', 'time': ''}, {'command': 'interface loopback 1', 'mode': 'Quick', 'time': ''}, {'command': 'ip address 172.16.4.0 255.255.255.0', 'mode': 'Quick', 'time': ''}, {'command': 'quit ', 'mode': 'Recv', 'time': ''}, {'command': 'ip route-static 10.10.10.0 255.255.255.0 10.10.11.1', 'mode': 'Quick', 'time': ''}, {'command': 'ip route-static 1.1.1.1 255.255.255.255 10.10.11.1', 'mode': 'Quick', 'time': ''}, {'command': 'ip route-static 2.2.2.2 255.255.255.255 10.10.11.1', 'mode': 'Quick', 'time': ''}, {'command': 'ip route-static 172.16.1.0 255.255.255.0 10.10.11.1', 'mode': 'Quick', 'time': ''}, {'command': 'ip route-static 172.16.2.0 255.255.255.0 10.10.11.1', 'mode': 'Quick', 'time': ''}, {'command': 'ip route-static 172.16.3.0 255.255.255.0 10.10.11.1', 'mode': 'Quick', 'time': ''}, {'command': 'quit ', 'mode': 'Recv', 'time': ''}]
# {'command': 'system-view ', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：system-view
# {'command': 'interface G 0/1', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：interface G 0/1
# {'command': 'ip address 10.10.11.2 255.255.255.0', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip address 10.10.11.2 255.255.255.0
# {'command': 'quit ', 'mode': 'Recv', 'time': ''}
# 执行Recv中，命令为：quit
# {'command': 'interface loopback 0', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：interface loopback 0
# {'command': 'ip address 3.3.3.3 255.255.255.255', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip address 3.3.3.3 255.255.255.255
# {'command': 'quit ', 'mode': 'Recv', 'time': ''}
# 执行Recv中，命令为：quit
# {'command': 'interface loopback 1', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：interface loopback 1
# {'command': 'ip address 172.16.4.0 255.255.255.0', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip address 172.16.4.0 255.255.255.0
# {'command': 'quit ', 'mode': 'Recv', 'time': ''}
# 执行Recv中，命令为：quit
# {'command': 'ip route-static 10.10.10.0 255.255.255.0 10.10.11.1', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip route-static 10.10.10.0 255.255.255.0 10.10.11.1
# {'command': 'ip route-static 1.1.1.1 255.255.255.255 10.10.11.1', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip route-static 1.1.1.1 255.255.255.255 10.10.11.1
# {'command': 'ip route-static 2.2.2.2 255.255.255.255 10.10.11.1', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip route-static 2.2.2.2 255.255.255.255 10.10.11.1
# {'command': 'ip route-static 172.16.1.0 255.255.255.0 10.10.11.1', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip route-static 172.16.1.0 255.255.255.0 10.10.11.1
# {'command': 'ip route-static 172.16.2.0 255.255.255.0 10.10.11.1', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip route-static 172.16.2.0 255.255.255.0 10.10.11.1
# {'command': 'ip route-static 172.16.3.0 255.255.255.0 10.10.11.1', 'mode': 'Quick', 'time': ''}
# 执行Quicky中，命令为：ip route-static 172.16.3.0 255.255.255.0 10.10.11.1
# {'command': 'quit ', 'mode': 'Recv', 'time': ''}
# 执行Recv中，命令为：quit
# 执行Quicky中，命令为：
# 执行Recv中，命令为：save
# 执行Recv中，命令为：Y
# 执行Recv中，命令为：
# 执行Recv中，命令为：Y
# ✅ 设备 AutoConfig_R3 配置完成并保存
